# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset('titanic')
print(data.shape)
# Out:
# (891, 15)

# %%
print(data.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.histplot(data=data,x='age',kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.countplot(data=data,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(data=data,x='class')
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.boxplot(data=data,x='class',y='fare')
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.boxplot(data=data,x='class',y='age')
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.barplot(data=data,x='class',y='survived')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.boxplot(data=data,x='class',y='survived',hue='sex')
# Out:
# <Axes: xlabel='class', ylabel='survived'>

# %%
sns.boxplot(data=data,x='sex',y='survived')
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.histplot(data=data,x='fare',kde=True,bins=30)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>
